# %% [markdown]
# Wir müssen nächste Woche eine 10 min Präsentation halten.

# %% [markdown]
# Ich habe kurz den Status berichtet. Bei uns ist alles in Ordnung.

# %% [markdown]
# Er nutzt die Kommandozeile um durch die Ordner zu navigieren.
#
# mkdir um ein Verzeichniss anzulegen
#
# cd um in den Ordner zu öffnen

# %% [markdown]
# git  - hauptbefehl um git zu starten.
#
# wenn man nur "git" eingibt, bekommt man eine liste aller möglichen befehle.
#
# mit "git init" wird ein neues git repository erstellt.

# %% [markdown]
# mir ls -al bekommt man die infos über die Dateien und Verzeichnisse. Dort erscheint nun auch der hinweis git

# %% [markdown]
# mit
# touch test.py wird die Datein test.py erstellt

# %% [markdown]
# mit git statur kann man den status der dateien sehen

# %% [markdown]
# mit git add test.py wird die datei zum git hinzugefügt.

# %% [markdown]
# mit git commit -m "message" kann man commits erstellen

# %% [markdown]
# Wie kann ich git installieren?

# %% [markdown]
# Wie funktioniert das login und die verknüfung mit einem Verzeichniss in der Cloud?

# %% [markdown]
# Wie geht das mit Gitlab an der TU?

# %% [markdown]
# Mit nano test.py macht man den Nano Editor auf um in die Datei schreiben zu können.

# %% [markdown]
#  mit -- help hinter einen Befehl bekommt man die Hilfe für diesen Befehl

# %% [markdown]
# mit git branch branchname kann meinen branch erstellen.

# %% [markdown]
# mit git checkout branchname welchsen wir auf den brachn
#
# dann zeigt git status, dass wir auf dem branch sind

# %% [markdown]
# mit cat test.py kann ich die Datei anzeigen

# %% [markdown]
# mit git merge branchname kann man einen branch in den aktuellen branch mergen

# %% [markdown]
# Am Master branch wird nie commmited, nur gemerged.
